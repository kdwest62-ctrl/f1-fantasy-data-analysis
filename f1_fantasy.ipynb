# %% [markdown]
# <a href="https://colab.research.google.com/github/kdwest62-ctrl/f1-fantasy/blob/main/f1_fantasy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

points = input('Fantasy points progression: ').split() # separated by spaces
data = list(map(lambda x: int(x), points))

x = [n for n in range(1, len(data) + 1)]
y = [n for n in data]
plt.plot(x, y, marker=".", markersize=10, color='blue')
plt.show()

# %%
values = []
updates = []
for num in range(1, 5 + 1):
  value = float(input(f"Driver {num} current value (M): "))
  values.append(value)
  update = float(input("Value update (M): "))
  updates.append(update)
for num in range(1, 2 + 1):
  value = float(input(f"Constructor {num} current value (M): "))
  values.append(value)
  update = float(input("Value update (M): "))
  updates.append(update)

team_value = sum(values)
total_updates = sum(updates)
print("-" * 8)
print(f"Current team value: {team_value}")
print(f"Total updates: {total_updates}")
print(f"New team value: {team_value + total_updates}")
# Out:
# Driver 1 current value (M): 10.4
# Value update (M): 0.6
# Driver 2 current value (M): 9.5
# Value update (M): 0.6
# Driver 3 current value (M): 13.3
# Value update (M): 0.6
# Driver 4 current value (M): 6.8
# Value update (M): 0.6
# Driver 5 current value (M): 6.6
# Value update (M): 0.6
# Constructor 1 current value (M): 11.7
# Value update (M): 0.6
# Constructor 2 current value (M): 5.6
# Value update (M): 0.6
# Current team value: 63.9
# Total updates: 4.2
# New team value: 68.1
