# %% [markdown]
# <a href="https://colab.research.google.com/github/kdwest62-ctrl/f1-fantasy/blob/main/circuit-speed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
circuits = {
    "AUS": "M",  # Australian GP
    "CHN": "M",  # Chinese GP
    "JPN": "M",  # Japanese GP
    "MIA": "M",  # Miami GP
    "MON": "L",  # Monaco GP
    "ESP": "M",  # Spanish GP
    "CAN": "M",  # Canadian GP
    "AUT": "H",  # Austrian GP
    "GBR": "H",  # British GP
    "BEL": "H",  # Belgian GP
    "HUN": "L",  # Hungarian GP
    "NED": "M",  # Dutch GP
    "ITA": "H",  # Italian GP
    "MAD": "M",  # Madrid Street Circuit
    "AZE": "H",  # Azerbaijan GP
    "SGP": "L",  # Singapore GP
    "USA": "M",  # United States GP
    "MEX": "H",  # Mexico City GP
    "BRA": "M",  # Sao Paulo GP
    "LVG": "H",  # Las Vegas GP
    "QAT": "M",  # Qatar GP
    "ABU": "M"   # Abu Dhabi GP
}

# %%
import matplotlib.pyplot as plt
import itertools

races = int(input("Number of races: "))
sliced_dict = dict(itertools.islice(circuits.items(), races))
